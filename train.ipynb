# %%
# !head /proc/cpuinfo

# %%
# !head -n 3 /proc/meminfo

# %%
# !nvidia-smi

# %%
# !cd ~/yolov5ori && git clone https://github.com/ultralytics/yolov5  # clone

# %%
# !cd ~/yolov5ori/yolov5 && git reset --hard f5b8f7d54c9fa69210da0177fec7ac2d9e4a627c

# %%
# !cd ~/yolov5ori/yolov5 && pip install -r requirements.txt
#!cd ~/yolov5 && pip install -r requirements.txt

# %%
# !pip install -U albumentations

# %%
# !pip uninstall opencv-python-headless==4.5.5.62 --yes

# %%
# !pip install opencv-python-headless==4.5.2.52

# %%
# !python ~/yolov5ori/yolov5/train.py --img 1080 --batch 16 --epochs 20 --weights '' --cfg ~/yolov5ori/yolov5/models/yolov5s.yaml --data ~/yolov5ori/yolov5/data/PBData.yaml --hyp ~/yolov5ori/yolov5/data/hyp.scratch.yaml --name ~/anaconda3/runs/train/pb_ori_20
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 v5.0-0-gf5b8f7d torch 1.10.2+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='/home/naroo135/yolov5ori/yolov5/models/yolov5s.yaml', data='/home/naroo135/yolov5ori/yolov5/data/PBData.yaml', device='', entity=None, epochs=20, evolve=False, exist_ok=False, global_rank=-1, hyp='/home/naroo135/yolov5ori/yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[1080, 1080], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='/home/naroo135/anaconda3/runs/train/pb_ori_20', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='/home/naroo135/anaconda3/runs/train/pb_ori_20', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='', workers=8, world_size=1)
# ...

# %%
# !python ~/yolov5ori/yolov5/train.py --img 1080 --batch 16 --epochs 20 --weights '' --cfg ~/yolov5ori/yolov5/models/yolov5s.yaml --data ~/yolov5ori/yolov5/data/PBData.yaml --hyp ~/yolov5ori/yolov5/data/hyp2.scratch.yaml --name ~/anaconda3/runs/train/pb_aug_20
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 v5.0-0-gf5b8f7d torch 1.10.2+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='/home/naroo135/yolov5ori/yolov5/models/yolov5s.yaml', data='/home/naroo135/yolov5ori/yolov5/data/PBData.yaml', device='', entity=None, epochs=20, evolve=False, exist_ok=False, global_rank=-1, hyp='/home/naroo135/yolov5ori/yolov5/data/hyp2.scratch.yaml', image_weights=False, img_size=[1080, 1080], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='/home/naroo135/anaconda3/runs/train/pb_aug_20', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='/home/naroo135/anaconda3/runs/train/pb_aug_20', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='', workers=8, world_size=1)
# ...

# %%
# !python ~/yolov5ori/yolov5/train.py --img 1080 --batch 16 --epochs 20 --weights '' --cfg ~/yolov5ori/yolov5/models/yolov5s.yaml --data ~/yolov5ori/yolov5/data/PBData.yaml --hyp ~/yolov5ori/yolov5/data/hyp4.scratch.yaml --name ~/anaconda3/runs/train/pb_aug3_20
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 v5.0-0-gf5b8f7d torch 1.10.2+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='/home/naroo135/yolov5ori/yolov5/models/yolov5s.yaml', data='/home/naroo135/yolov5ori/yolov5/data/PBData.yaml', device='', entity=None, epochs=20, evolve=False, exist_ok=False, global_rank=-1, hyp='/home/naroo135/yolov5ori/yolov5/data/hyp4.scratch.yaml', image_weights=False, img_size=[1080, 1080], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='/home/naroo135/anaconda3/runs/train/pb_aug3_20', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='/home/naroo135/anaconda3/runs/train/pb_aug3_20', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='', workers=8, world_size=1)
# ...

# %%
# !python ~/yolov5ori/yolov5/train.py --img 1080 --batch 16 --epochs 20 --weights '' --cfg ~/yolov5ori/yolov5/models/yolov5a.yaml --data ~/yolov5ori/yolov5/data/PBData.yaml --hyp ~/yolov5ori/yolov5/data/hyp.scratch.yaml --name ~/anaconda3/runs/train/pb_mod_20
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 v5.0-0-gf5b8f7d torch 1.10.2+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='/home/naroo135/yolov5ori/yolov5/models/yolov5a.yaml', data='/home/naroo135/yolov5ori/yolov5/data/PBData.yaml', device='', entity=None, epochs=20, evolve=False, exist_ok=False, global_rank=-1, hyp='/home/naroo135/yolov5ori/yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[1080, 1080], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='/home/naroo135/anaconda3/runs/train/pb_mod_20', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='/home/naroo135/anaconda3/runs/train/pb_mod_20', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='', workers=8, world_size=1)
# ...

# %%
# !python ~/yolov5ori/yolov5/train.py --img 1080 --batch 16 --epochs 20 --weights '' --cfg ~/yolov5ori/yolov5/models/yolov5s.yaml --data ~/yolov5ori/yolov5/data/PBSDData.yaml --hyp ~/yolov5ori/yolov5/data/hyp.scratch.yaml --name ~/anaconda3/runs/train/pb_sd_ori_20
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 v5.0-0-gf5b8f7d torch 1.10.2+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='/home/naroo135/yolov5ori/yolov5/models/yolov5s.yaml', data='/home/naroo135/yolov5ori/yolov5/data/PBSDData.yaml', device='', entity=None, epochs=20, evolve=False, exist_ok=False, global_rank=-1, hyp='/home/naroo135/yolov5ori/yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[1080, 1080], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='/home/naroo135/anaconda3/runs/train/pb_sd_ori_20', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='/home/naroo135/anaconda3/runs/train/pb_sd_ori_20', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='', workers=8, world_size=1)
# ...

# %%
# !python ~/yolov5ori/yolov5/train.py --img 1080 --batch 8 --epochs 20 --weights '' --cfg ~/yolov5ori/yolov5/models/yolov5m.yaml --data ~/yolov5ori/yolov5/data/PBData.yaml --hyp ~/yolov5ori/yolov5/data/hyp.scratch.yaml --name ~/anaconda3/runs/train/pb_ori_20m
# Out:
# github: skipping check (not a git repository)
# YOLOv5 🚀 v5.0-0-gf5b8f7d torch 1.10.2+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160.6875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='/home/naroo135/yolov5ori/yolov5/models/yolov5m.yaml', data='/home/naroo135/yolov5ori/yolov5/data/PBData.yaml', device='', entity=None, epochs=20, evolve=False, exist_ok=False, global_rank=-1, hyp='/home/naroo135/yolov5ori/yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[1080, 1080], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='/home/naroo135/anaconda3/runs/train/pb_ori_20m', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='/home/naroo135/anaconda3/runs/train/pb_ori_20m', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='', workers=8, world_size=1)
# ...
